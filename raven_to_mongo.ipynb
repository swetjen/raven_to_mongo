# %%
###
# Used to update the web app with updated recall information from RavenDB.
###

from pymongo import MongoClient
import ravendb  # DOCUMENTATION:  https://github.com/firegrass/ravendb-py
import json
from datetime import datetime
import random
from tabulate import tabulate

ENABLE_DEV = True              # TRUE = Use Localhost DB
UPDATE_DB = True              # Write Query to Mongo DB

# SOURCE SETTINGS
RAVEN_URL      = "http://pcvalt-ravendb.cloudapp.net:8080"
RAVEN_DB       = 'RecallGenius'
RAVEN_INDEXS   = ['CarByLotIndex',
                  'LotIndex',
                  'Auto/Customers/ByUrlSuffix'] # These become our collections in Meteor...


# DESTINATION SETTINGS
MONGO_DEV      = 'mongodb://127.0.0.1:3001/meteor'  # Likely Local Instance
MONGO_URL      = 'mongodb://heroku_x9r2g76x:vrl27eqtsd9qhqe7kb6q5445bs@ds027489.mlab.com:27489/heroku_x9r2g76x'  # Prod Instance on Modulus


def viz_report(store,label):
    # Accepts raven store and returns table summry of its contents
    result = []
        
    if label == 'mongo'.lower():
        for key,value in store.iteritems():
            y = [key,value]
            result.append(y)
            
    else:
        for key in store.keys():
            y = [key, str(len(store[key]))]
            result.append(y)

    return tabulate(result, headers=[label, 'Records'])


if __name__ == '__main__':
    
    # CREATE RAVEN OBJECT
    c1 = ravendb.store(url = RAVEN_URL, database = RAVEN_DB)
    session = c1.createSession()
    results = session.query('CarByLotIndex', query={})
    
    # SAVE OUR QUERY RESULTS
    store = {}
    
    # ITERATE INDEXS AND STORE RESULTS
    for index in RAVEN_INDEXS:
        raven = session.query(index, query={})
        raven = raven['Results']
        store[index] = raven
        del raven

    # Show our work...
    print '--------\nRAVEN DB\n--------\nURL: %s\nDB:  %s\n' % (RAVEN_URL, RAVEN_DB)
    print viz_report(store,'Raven')
# Out:
# --------
# RAVEN DB
# --------
# URL: http://pcvalt-ravendb.cloudapp.net:8080
# DB:  RecallGenius
#
# Raven                         Records
# --------------------------  ---------
# LotIndex                          127
# Auto/Customers/ByUrlSuffix          3
# CarByLotIndex                     657

# %%
store['Auto/Customers/ByUrlSuffix']
# Out:
# [{u'@metadata': {u'@etag': u'01000000-0000-0005-0000-000000000D47',
#    u'@id': u'customers/35',
#    u'Last-Modified': u'2016-11-15T23:17:48.5066637Z',
#    u'Non-Authoritative-Information': False,
#    u'Raven-Clr-Type': u'RecallGenius.RavenDb.Models.Customer, RecallGenius.RavenDb',
#    u'Raven-Entity-Name': u'Customers',
#    u'Raven-Last-Modified': u'2016-11-15T23:17:48.5066637',
#    u'Raven-Replication-Source': u'dec40d7d-4294-49e6-ba65-41867481b7c0',
#    u'Raven-Replication-Version': 6986,
#    u'Temp-Index-Score': 1.0},
#   u'Location': {u'Address': u'10133 US Hwy 19',
#    u'City': u'Port Richey',
#    u'Position': {u'Latitude': 28.30535, u'Longitude': -82.703621},
#    u'State': u'Florida',
#    u'Zip': 34668},
#   u'Name': u'Ed Moris Autoplaza',
#   u'Regions': [{u'Bounds': [{u'Latitude': 28.320235, u'Longitude': -82.724377},
#      {u'Latitude': 28.322249, u'Longitude': -82.661012},
#      {u'Latitude': 28.266154, u'Longitude': -82.747976},
# ...

# %%
tracking = {}

for key in store:

    db.drop_collection(key)
    db.create_collection(key)
    
    collection = db[key]
    
    tracking[key] = 0

    for each in store[key]:

        x = each.copy()
        break
    break

print x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-1a6edd7b5a97> in <module>()
#       3 for key in store:
#       4
# ----> 5     db.drop_collection(key)
#       6     db.create_collection(key)
#       7
#
# NameError: name 'db' is not defined

# %%
x

# %%
i.keys()

# %%
json.dumps(x)

# %%
x = {'CarByLotIndex': 657, 'Auto/Customers/ByUrlSuffix': 3, 'LotIndex': 127}

ILLEGAL_CHARS = ['/','@']

def viz_report(store,label):
    # Accepts raven store and returns table summry of its contents
    result = []
        
    if label == 'mongo'.lower():
        for key,value in store.iteritems():
            y = [key,value]
            result.append(y)
            
    else:
        for key in store.keys():
            y = [key, str(len(store[key]))]
            result.append(y)

    return tabulate(result, headers=[label, 'Records'])


print viz_report(x,'mongo')
x = x

# %%
print x, type(x)

for key in x.keys(): x[key.lower().translate(None,'/')] = x.pop(key)
    
print x

# %%
y = 'auto/customers/byurlsuffix'

table = ['/']

q = y.translate(None,'/')  

q

# %%
store['Auto/Customers/ByUrlSuffix']

# For customers, drop the 'customers' part and just use the arbitrary #
#  e.g., 
# For Cars, id = vin
# For Lots,
# Out:
# [{u'@metadata': {u'@etag': u'01000000-0000-0005-0000-000000000D47',
#    u'@id': u'customers/35',
#    u'Last-Modified': u'2016-11-15T23:17:48.5066637Z',
#    u'Non-Authoritative-Information': False,
#    u'Raven-Clr-Type': u'RecallGenius.RavenDb.Models.Customer, RecallGenius.RavenDb',
#    u'Raven-Entity-Name': u'Customers',
#    u'Raven-Last-Modified': u'2016-11-15T23:17:48.5066637',
#    u'Raven-Replication-Source': u'dec40d7d-4294-49e6-ba65-41867481b7c0',
#    u'Raven-Replication-Version': 6986,
#    u'Temp-Index-Score': 1.0},
#   u'Location': {u'Address': u'10133 US Hwy 19',
#    u'City': u'Port Richey',
#    u'Position': {u'Latitude': 28.30535, u'Longitude': -82.703621},
#    u'State': u'Florida',
#    u'Zip': 34668},
#   u'Name': u'Ed Moris Autoplaza',
#   u'Regions': [{u'Bounds': [{u'Latitude': 28.320235, u'Longitude': -82.724377},
#      {u'Latitude': 28.322249, u'Longitude': -82.661012},
#      {u'Latitude': 28.266154, u'Longitude': -82.747976},
# ...

# %%
# Given an input set of lat, lomg, return an 50m square area around it.


# figure out how to calculate 50m

# %%
x = 'customers/33'

len(x)

p = x[10::1]

p
# Out:
# '33'

# %%
store['CarByLotIndex'][0]['@metadata']['@id']
q = store['CarByLotIndex'][0]

# %%
store['LotIndex'][0]['@metadata']['@id']

q = store['LotIndex'][0]

# %%
p = store['Auto/Customers/ByUrlSuffix'][0]['@metadata']['@id']

q = store['Auto/Customers/ByUrlSuffix'][0]

# %%
def raven_id_to_mongo_id(store_object):
    p = store_object['@metadata']['@id']
    return p[p.index('/')+1::1]

# %%
print raven_id_to_mongo_id(q)
# Out:
# <type 'unicode'>
# 1FTEX15N3TKA58902
